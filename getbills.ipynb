# %%
#import dependencies
from urllib.request import urlopen
import json, pprint

# %%
# set url to get most recent parliament session bills and read as json
url = "https://www.parl.ca/legisinfo/en/bills/json"
response = urlopen(url)
data_json = json.loads(response.read())
# pprint.pp(data_json)
# Out:
# [{'SearchScore': 1.0,
#   'BillId': 11473483,
#   'BillNumberPrefix': None,
#   'BillNumber': 0,
#   'BillNumberSuffix': None,
#   'BillNumberFormatted': 'S-1',
#   'LongTitleEn': 'An Act relating to railways',
#   'LongTitleFr': 'Loi concernant les chemins de fer',
#   'ShortTitleEn': '',
#   'ShortTitleFr': '',
#   'LatestBillMilestoneId': 60043,
#   'LatestCompletedMajorStageEn': 'First reading',
#   'LatestCompletedMajorStageFr': 'Première lecture',
#   'LatestCompletedMajorStageChamberId': 2,
#   'DidReinstateFromPreviousSession': False,
#   'PassedHouseFirstReadingDateTime': None,
#   'PassedHouseSecondReadingDateTime': None,
#   'PassedHouseThirdReadingDateTime': None,
#   'PassedSenateFirstReadingDateTime': '2021-11-22T19:00:00-05:00',
#   'PassedSenateSecondReadingDateTime': None,
#   'PassedSenateThirdReadingDateTime': None,
#   'ReceivedRoyalAssentDateTime': None,
#   'ParlSessionCode': '44-1',
# ...

# %% [markdown]
# Get usable data from the json. Focus on BillId, BillNumberFormatted, LongTitleEn, LongTitleFr, LatestCompletedMajorStageEn, LatestCompletedMajorStageFr, ParlSessionCode, LatestActivityEn, LatestActivityFr

# %%
keys_list = list(data_json[0].keys())
keys_list
# Out:
# ['SearchScore',
#  'BillId',
#  'BillNumberPrefix',
#  'BillNumber',
#  'BillNumberSuffix',
#  'BillNumberFormatted',
#  'LongTitleEn',
#  'LongTitleFr',
#  'ShortTitleEn',
#  'ShortTitleFr',
#  'LatestBillMilestoneId',
#  'LatestCompletedMajorStageEn',
#  'LatestCompletedMajorStageFr',
#  'LatestCompletedMajorStageChamberId',
#  'DidReinstateFromPreviousSession',
#  'PassedHouseFirstReadingDateTime',
#  'PassedHouseSecondReadingDateTime',
#  'PassedHouseThirdReadingDateTime',
#  'PassedSenateFirstReadingDateTime',
#  'PassedSenateSecondReadingDateTime',
#  'PassedSenateThirdReadingDateTime',
#  'ReceivedRoyalAssentDateTime',
#  'ParlSessionCode',
#  'ParlSessionEn',
#  'ParlSessionFr',
#  'ParliamentNumber',
#  'SessionNumber',
#  'OriginatingChamberId',
#  'BillTypeId',
#  'BillTypeEn',
#  'BillTypeFr',
#  'CurrentStatusId',
#  'CurrentStatusEn',
#  'CurrentStatusFr',
#  'MinistryId',
#  'SponsorId',
#  'SponsorEn',
#  'SponsorFr',
#  'PoliticalAffiliationId',
# ...
